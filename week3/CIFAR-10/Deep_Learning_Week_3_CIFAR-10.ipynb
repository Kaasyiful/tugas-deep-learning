# %% [markdown]
# # Pengerjaan Tugas Deep Learning menggunakan PyTorch and TensorFlow (Week 3, CIFAR-10 Dataset)

# %% [markdown]
# # Persiapan: Instalasi library

# %%
# !pip install numpy matplotlib scikit-learn torch tensorflow tensorflow-datasets
# pip install numpy matplotlib scikit-learn torch tensorflow tensorflow-datasets
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cpu)
# Collecting tensorflow
#   Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.11/dist-packages (4.9.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Collecting google-pasta>=0.1.1 (from tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.71.0)
# Collecting tensorboard~=2.19.0 (from tensorflow)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.5.1)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.7.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.12.2)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.2.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (19.0.1)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.16.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.67.1)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.1)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (3.21.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.3.6)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.19.0->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.19.0->tensorflow)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->tensorflow-datasets) (25.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from simple_parsing->tensorflow-datasets) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.11/dist-packages (from tensorflow-metadata->tensorflow-datasets) (1.69.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (644.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 644.9/644.9 MB 143.4 MB/s eta 0:00:01

# %% [markdown]
# # Deep Learning Menggunakan PyTorch (MLP dan CNN)

# %% [markdown]
# ### 1. Mengimpor Library yang Dibutuhkan

# %%
# Import library yang diperlukan
import torch # Library utama untuk deep learning
import torch.nn as nn # Library untuk neural network
import torch.optim as optim # Library untuk optimizers
import torch.nn.functional as F # Library untuk fungsi aktivasi dan loss functions
import torchvision # Library untuk computer vision
import torchvision.transforms as transforms # Library untuk transformasi data
import numpy as np # Library untuk manipulasi array
import matplotlib.pyplot as plt # Library untuk visualisasi data
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, auc, confusion_matrix

# Mengatur device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # Menggunakan GPU jika tersedia, jika tidak menggunakan CPU
print(f"Menggunakan device: {device}")
# Out:
# Menggunakan device: cpu

# %% [markdown]
# ### 2. Mendefinisikan Transformasi Data dan Memuat Dataset CIFAR-10

# %%
# Data transformations
# Transformasi data untuk augmentasi dan normalisasi
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    ])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    ])

# Memuat dataset CIFAR-10
trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform_train)
trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=128, shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform_test)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=128, shuffle=False, num_workers=2)

# Kelas untuk CIFAR-10
classes = ('plane', 'car', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# ### 3. Menyiapkan Fungsi Pelatihan dan Validasi

# %%
# Fungsi untuk melatih model
def train_model(model, trainloader, criterion, optimizer, scheduler, epochs=100):
    train_losses = [] # List untuk menyimpan loss
    train_accuracies = [] # List untuk menyimpan akurasi

    # Perulangan untuk setiap epoch
    for epoch in range(epochs):
        running_loss = 0.0
        correct = 0
        total = 0

        model.train() # Mengatur model ke mode training
        # Perulangan untuk setiap batch dalam trainloader
        for i, data in enumerate(trainloader, 0):
            inputs, labels = data # Mengambil data dan label dari batch
            # Memindahkan data dan label ke device (GPU/CPU)
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad() # Mengatur gradien ke nol sebelum backward pass

            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            # Menghitung akurasi
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        # Menghitung rata-rata loss dan akurasi untuk epoch ini
        epoch_loss = running_loss / len(trainloader)
        epoch_acc = 100 * correct / total

        # Validasi dan penyesuaian learning rate
        val_loss, val_acc = evaluate_model(model, testloader, criterion)
        scheduler.step(val_loss) # Menyesuaikan learning rate berdasarkan validasi loss

        # Menyimpan loss dan akurasi untuk epoch ini
        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f'Epoch {epoch+1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.2f}%, '
              f'Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc:.2f}%')

    return train_losses, train_accuracies, val_loss, val_acc

# Fungsi untuk evaluasi model
def evaluate_model(model, dataloader, criterion):
    model.eval() # Mengatur model ke mode evaluasi
    val_loss = 0.0
    correct = 0
    total = 0

    # Perulangan untuk setiap batch dalam dataloader
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            val_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    return val_loss / len(dataloader), 100 * correct / total

# Fungsi untuk mendapatkan prediksi lengkap
def get_all_predictions(model, dataloader):
    model.eval()
    all_labels = []
    all_predictions = []
    all_probabilities = []

    # Perulangan untuk setiap batch dalam dataloader
    with torch.no_grad():
        for data in dataloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            probabilities = F.softmax(outputs, dim=1)

            _, predicted = torch.max(outputs.data, 1)

            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(predicted.cpu().numpy())
            all_probabilities.extend(probabilities.cpu().numpy())

    return np.array(all_labels), np.array(all_predictions), np.array(all_probabilities)

# %% [markdown]
# ### 4. Menyiapkan Fungsi Evaluasi

# %%
# Metrik evaluasi yang digunakan antara lain akurasi, presisi, recall, f1-score, dan ROC AUC
# Fungsi untuk menghitung metrik evaluasi
def evaluate_metrics(y_true, y_pred, y_prob):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='macro')
    recall = recall_score(y_true, y_pred, average='macro')
    f1 = f1_score(y_true, y_pred, average='macro')
    roc_auc = roc_auc_score(y_true, y_prob, average='macro', multi_class='ovr')

    return accuracy, precision, recall, f1, roc_auc

# %% [markdown]
# ### 5. Menyiapkan Fungsi Visualisasi

# %%
# Fungsi untuk menampilkan plot loss dan akurasi
def visualize_results(train_losses, train_accuracies):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.title('Train Loss vs Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Train Accuracy', color='orange')
    plt.title('Train Accuracy vs Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Fungsi untuk menampilkan ROC curve
def visualize_roc_curve(y_true, y_scores):
    # Binarize the output
    n_classes = y_scores.shape[1]
    y_true_bin = label_binarize(y_true, classes=np.arange(n_classes))

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y_true_bin.ravel(), y_scores.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # Plot ROC curve for a specific class (e.g., class 1)
    plt.figure(figsize=(8, 6))
    plt.plot(fpr[1], tpr[1], label=f'ROC curve (area = {roc_auc[1]:.2f})')  # Example: Plotting for class 1
    plt.plot([0, 1], [0, 1], 'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

# Fungsi untuk menampilkan confusion matrix
def visualize_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    plt.matshow(cm, cmap='Blues')
    plt.colorbar()
    plt.title('Confusion Matrix')

    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, f'{cm[i, j] / cm.sum() * 100:.1f}%', ha='center', va='bottom', color='lavender' if cm[i, j] > cm.max() / 2 else 'black')

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %% [markdown]
# ## A. MLP CIFAR-10 dengan PyTorch

# %% [markdown]
# ### 1. Menyusun Model MLP Sederhana

# %%
# Mendefinisikan model MLP
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        # Input size: 32x32x3 = 3072
        self.flatten = nn.Flatten()

        # Fully connected layers
        self.fc1 = nn.Linear(32 * 32 * 3, 2048)
        self.bn1 = nn.BatchNorm1d(2048)
        self.dropout1 = nn.Dropout(0.5)

        self.fc2 = nn.Linear(2048, 1024)
        self.bn2 = nn.BatchNorm1d(1024)
        self.dropout2 = nn.Dropout(0.33)

        self.fc3 = nn.Linear(1024, 512)
        self.bn3 = nn.BatchNorm1d(512)
        self.dropout3 = nn.Dropout(0.25)

        self.fc4 = nn.Linear(512, 256)
        self.bn4 = nn.BatchNorm1d(256)
        self.dropout4 = nn.Dropout(0.2)

        self.fc5 = nn.Linear(256, 128)
        self.bn5 = nn.BatchNorm1d(128)
        self.dropout5 = nn.Dropout(0.2)

        self.fc6 = nn.Linear(128, 64)
        self.bn6 = nn.BatchNorm1d(64)
        self.dropout6 = nn.Dropout(0.2)

        self.fc7 = nn.Linear(64, len(classes)) # Output size: 10 (jumlah kelas CIFAR-10)

    # Fungsi forward untuk melakukan forward pass
    def forward(self, x):
        x = self.flatten(x)

        x = F.relu(self.bn1(self.fc1(x)))
        x = self.dropout1(x)

        x = F.relu(self.bn2(self.fc2(x)))
        x = self.dropout2(x)

        x = F.relu(self.bn3(self.fc3(x)))
        x = self.dropout3(x)

        x = F.relu(self.bn4(self.fc4(x)))
        x = self.dropout4(x)

        x = F.relu(self.bn5(self.fc5(x)))
        x = self.dropout5(x)

        x = F.relu(self.bn6(self.fc6(x)))
        x = self.dropout6(x)

        x = self.fc7(x)

        return x

# Inisialisasi model
model_mlp = MLP().to(device)
print(model_mlp)
# Out:
# MLP(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=3072, out_features=2048, bias=True)
#   (bn1): BatchNorm1d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout1): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=2048, out_features=1024, bias=True)
#   (bn2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout2): Dropout(p=0.33, inplace=False)
#   (fc3): Linear(in_features=1024, out_features=512, bias=True)
#   (bn3): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout3): Dropout(p=0.25, inplace=False)
#   (fc4): Linear(in_features=512, out_features=256, bias=True)
#   (bn4): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout4): Dropout(p=0.2, inplace=False)
#   (fc5): Linear(in_features=256, out_features=128, bias=True)
#   (bn5): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout5): Dropout(p=0.2, inplace=False)
#   (fc6): Linear(in_features=128, out_features=64, bias=True)
#   (bn6): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout6): Dropout(p=0.2, inplace=False)
#   (fc7): Linear(in_features=64, out_features=10, bias=True)
# )

# %% [markdown]
# ### 2. Menyiapkan Optimizer dan Loss Function

# %%
# Inisialisasi loss function dan optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_mlp.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.1, verbose=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %% [markdown]
# ### 3. Melatih Model

# %%
# Melatih model MLP dengan data augmentation
print("Melatih model MLP...")
train_losses_mlp, train_accuracies_mlp, val_losses_mlp, val_accuracies_mlp = train_model(model_mlp, trainloader, criterion, optimizer, scheduler, epochs=150)

# Mengevaluasi model
print("Evaluasi akhir model...")
test_loss_mlp, test_accuracy_mlp = evaluate_model(model_mlp, testloader, criterion)
print(f"Final Test Loss: {test_loss_mlp:.4f}, Test Accuracy: {test_accuracy_mlp:.2f}%")
# Out:
# Melatih model MLP...
# Epoch 1, Loss: 1.9601, Accuracy: 28.10%, Val Loss: 1.7496, Val Accuracy: 35.76%
# Epoch 2, Loss: 1.7963, Accuracy: 34.73%, Val Loss: 1.6554, Val Accuracy: 39.75%
# Epoch 3, Loss: 1.7311, Accuracy: 37.74%, Val Loss: 1.6036, Val Accuracy: 42.56%
# Epoch 4, Loss: 1.6886, Accuracy: 39.06%, Val Loss: 1.5458, Val Accuracy: 43.76%
# Epoch 5, Loss: 1.6538, Accuracy: 40.61%, Val Loss: 1.4883, Val Accuracy: 46.48%
# Epoch 6, Loss: 1.6293, Accuracy: 41.62%, Val Loss: 1.4784, Val Accuracy: 46.57%
# Epoch 7, Loss: 1.6085, Accuracy: 42.48%, Val Loss: 1.4995, Val Accuracy: 45.73%
# Epoch 8, Loss: 1.5913, Accuracy: 43.17%, Val Loss: 1.4157, Val Accuracy: 49.06%
# Epoch 9, Loss: 1.5750, Accuracy: 43.76%, Val Loss: 1.4375, Val Accuracy: 48.64%
# Epoch 10, Loss: 1.5577, Accuracy: 44.09%, Val Loss: 1.4280, Val Accuracy: 48.41%
# Epoch 11, Loss: 1.5413, Accuracy: 44.54%, Val Loss: 1.3887, Val Accuracy: 49.66%
# Epoch 12, Loss: 1.5270, Accuracy: 45.45%, Val Loss: 1.3929, Val Accuracy: 50.21%
# Epoch 13, Loss: 1.5228, Accuracy: 45.48%, Val Loss: 1.3542, Val Accuracy: 51.14%
# Epoch 14, Loss: 1.5068, Accuracy: 46.16%, Val Loss: 1.3640, Val Accuracy: 50.65%
# Epoch 15, Loss: 1.4993, Accuracy: 46.48%, Val Loss: 1.3563, Val Accuracy: 51.39%
# Epoch 16, Loss: 1.4913, Accuracy: 46.64%, Val Loss: 1.3269, Val Accuracy: 52.65%
# Epoch 17, Loss: 1.4801, Accuracy: 47.06%, Val Loss: 1.3158, Val Accuracy: 52.47%
# Epoch 18, Loss: 1.4662, Accuracy: 47.48%, Val Loss: 1.3041, Val Accuracy: 53.42%
# Epoch 19, Loss: 1.4626, Accuracy: 48.06%, Val Loss: 1.3093, Val Accuracy: 53.79%
# Epoch 20, Loss: 1.4539, Accuracy: 48.07%, Val Loss: 1.2999, Val Accuracy: 53.39%
# Epoch 21, Loss: 1.4474, Accuracy: 48.48%, Val Loss: 1.2819, Val Accuracy: 54.46%
# Epoch 22, Loss: 1.4425, Accuracy: 48.49%, Val Loss: 1.3027, Val Accuracy: 53.61%
# Epoch 23, Loss: 1.4271, Accuracy: 49.06%, Val Loss: 1.2973, Val Accuracy: 52.95%
# Epoch 24, Loss: 1.4288, Accuracy: 49.15%, Val Loss: 1.2656, Val Accuracy: 54.60%
# Epoch 25, Loss: 1.4204, Accuracy: 49.34%, Val Loss: 1.2727, Val Accuracy: 54.29%
# Epoch 26, Loss: 1.4069, Accuracy: 49.81%, Val Loss: 1.2713, Val Accuracy: 54.42%
# Epoch 27, Loss: 1.4078, Accuracy: 49.80%, Val Loss: 1.2536, Val Accuracy: 55.72%
# Epoch 28, Loss: 1.3972, Accuracy: 50.26%, Val Loss: 1.2397, Val Accuracy: 55.52%
# Epoch 29, Loss: 1.3947, Accuracy: 50.35%, Val Loss: 1.2335, Val Accuracy: 56.25%
# Epoch 30, Loss: 1.3878, Accuracy: 50.54%, Val Loss: 1.2354, Val Accuracy: 56.18%
# Epoch 31, Loss: 1.3810, Accuracy: 50.98%, Val Loss: 1.2198, Val Accuracy: 56.62%
# Epoch 32, Loss: 1.3771, Accuracy: 51.06%, Val Loss: 1.2343, Val Accuracy: 56.19%
# Epoch 33, Loss: 1.3687, Accuracy: 51.30%, Val Loss: 1.2225, Val Accuracy: 56.72%
# Epoch 34, Loss: 1.3694, Accuracy: 51.39%, Val Loss: 1.2258, Val Accuracy: 56.34%
# Epoch 35, Loss: 1.3604, Accuracy: 51.81%, Val Loss: 1.2176, Val Accuracy: 56.61%
# Epoch 36, Loss: 1.3535, Accuracy: 51.87%, Val Loss: 1.2151, Val Accuracy: 56.86%
# Epoch 37, Loss: 1.3526, Accuracy: 52.06%, Val Loss: 1.2327, Val Accuracy: 56.00%
# Epoch 38, Loss: 1.3538, Accuracy: 51.78%, Val Loss: 1.2028, Val Accuracy: 57.07%
# Epoch 39, Loss: 1.3404, Accuracy: 52.25%, Val Loss: 1.1970, Val Accuracy: 56.99%
# Epoch 40, Loss: 1.3363, Accuracy: 52.70%, Val Loss: 1.2021, Val Accuracy: 56.91%
# Epoch 41, Loss: 1.3344, Accuracy: 52.55%, Val Loss: 1.1899, Val Accuracy: 57.78%
# Epoch 42, Loss: 1.3314, Accuracy: 52.69%, Val Loss: 1.1860, Val Accuracy: 57.59%
# Epoch 43, Loss: 1.3303, Accuracy: 52.92%, Val Loss: 1.1890, Val Accuracy: 57.75%
# Epoch 44, Loss: 1.3174, Accuracy: 53.44%, Val Loss: 1.1859, Val Accuracy: 57.96%
# Epoch 45, Loss: 1.3157, Accuracy: 53.39%, Val Loss: 1.1683, Val Accuracy: 58.99%
# Epoch 46, Loss: 1.3113, Accuracy: 53.74%, Val Loss: 1.1785, Val Accuracy: 58.28%
# Epoch 47, Loss: 1.3088, Accuracy: 53.17%, Val Loss: 1.1608, Val Accuracy: 58.78%
# Epoch 48, Loss: 1.3034, Accuracy: 53.99%, Val Loss: 1.1758, Val Accuracy: 58.34%
# Epoch 49, Loss: 1.2989, Accuracy: 53.98%, Val Loss: 1.1658, Val Accuracy: 58.97%
# Epoch 50, Loss: 1.3001, Accuracy: 54.13%, Val Loss: 1.1548, Val Accuracy: 58.72%
# Epoch 51, Loss: 1.2902, Accuracy: 54.35%, Val Loss: 1.1551, Val Accuracy: 58.74%
# Epoch 52, Loss: 1.2901, Accuracy: 54.42%, Val Loss: 1.1681, Val Accuracy: 58.62%
# Epoch 53, Loss: 1.2875, Accuracy: 54.44%, Val Loss: 1.1445, Val Accuracy: 59.09%
# Epoch 54, Loss: 1.2861, Accuracy: 54.23%, Val Loss: 1.1407, Val Accuracy: 59.32%
# Epoch 55, Loss: 1.2777, Accuracy: 54.90%, Val Loss: 1.1420, Val Accuracy: 59.41%
# Epoch 56, Loss: 1.2809, Accuracy: 54.77%, Val Loss: 1.1267, Val Accuracy: 59.62%
# Epoch 57, Loss: 1.2755, Accuracy: 54.90%, Val Loss: 1.1326, Val Accuracy: 59.72%
# Epoch 58, Loss: 1.2667, Accuracy: 55.06%, Val Loss: 1.1294, Val Accuracy: 59.90%
# Epoch 59, Loss: 1.2692, Accuracy: 54.91%, Val Loss: 1.1410, Val Accuracy: 59.58%
# Epoch 60, Loss: 1.2631, Accuracy: 55.13%, Val Loss: 1.1297, Val Accuracy: 59.84%
# Epoch 61, Loss: 1.2601, Accuracy: 55.36%, Val Loss: 1.1301, Val Accuracy: 59.94%
# Epoch 62, Loss: 1.2612, Accuracy: 55.21%, Val Loss: 1.1166, Val Accuracy: 60.08%
# Epoch 63, Loss: 1.2562, Accuracy: 55.80%, Val Loss: 1.1194, Val Accuracy: 60.58%
# Epoch 64, Loss: 1.2495, Accuracy: 55.77%, Val Loss: 1.1189, Val Accuracy: 60.16%
# Epoch 65, Loss: 1.2504, Accuracy: 55.88%, Val Loss: 1.1257, Val Accuracy: 59.89%
# Epoch 66, Loss: 1.2445, Accuracy: 55.85%, Val Loss: 1.1224, Val Accuracy: 60.18%
# Epoch 67, Loss: 1.2407, Accuracy: 55.97%, Val Loss: 1.1174, Val Accuracy: 60.67%
# Epoch 68, Loss: 1.2429, Accuracy: 56.12%, Val Loss: 1.1075, Val Accuracy: 60.47%
# Epoch 69, Loss: 1.2325, Accuracy: 56.34%, Val Loss: 1.1097, Val Accuracy: 60.50%
# Epoch 70, Loss: 1.2362, Accuracy: 56.28%, Val Loss: 1.1080, Val Accuracy: 60.33%
# Epoch 71, Loss: 1.2323, Accuracy: 56.62%, Val Loss: 1.1045, Val Accuracy: 60.46%
# Epoch 72, Loss: 1.2307, Accuracy: 56.67%, Val Loss: 1.1033, Val Accuracy: 60.76%
# Epoch 73, Loss: 1.2277, Accuracy: 56.83%, Val Loss: 1.1114, Val Accuracy: 60.16%
# Epoch 74, Loss: 1.2229, Accuracy: 56.73%, Val Loss: 1.0944, Val Accuracy: 60.84%
# Epoch 75, Loss: 1.2236, Accuracy: 56.80%, Val Loss: 1.1020, Val Accuracy: 60.60%
# Epoch 76, Loss: 1.2220, Accuracy: 56.72%, Val Loss: 1.1040, Val Accuracy: 60.61%
# Epoch 77, Loss: 1.2186, Accuracy: 56.93%, Val Loss: 1.0937, Val Accuracy: 60.91%
# Epoch 78, Loss: 1.2120, Accuracy: 57.09%, Val Loss: 1.0831, Val Accuracy: 61.80%
# Epoch 79, Loss: 1.2181, Accuracy: 56.81%, Val Loss: 1.0988, Val Accuracy: 60.33%
# Epoch 80, Loss: 1.2110, Accuracy: 57.27%, Val Loss: 1.0941, Val Accuracy: 60.81%
# Epoch 81, Loss: 1.2067, Accuracy: 57.12%, Val Loss: 1.0828, Val Accuracy: 61.33%
# Epoch 82, Loss: 1.2056, Accuracy: 57.28%, Val Loss: 1.0816, Val Accuracy: 61.52%
# Epoch 83, Loss: 1.2047, Accuracy: 57.45%, Val Loss: 1.0827, Val Accuracy: 61.21%
# Epoch 84, Loss: 1.2043, Accuracy: 57.67%, Val Loss: 1.0826, Val Accuracy: 61.40%
# Epoch 85, Loss: 1.1971, Accuracy: 57.63%, Val Loss: 1.0796, Val Accuracy: 61.51%
# Epoch 86, Loss: 1.1985, Accuracy: 57.56%, Val Loss: 1.0775, Val Accuracy: 61.52%
# Epoch 87, Loss: 1.1967, Accuracy: 57.66%, Val Loss: 1.0705, Val Accuracy: 62.09%
# Epoch 88, Loss: 1.1949, Accuracy: 57.97%, Val Loss: 1.0778, Val Accuracy: 61.75%
# Epoch 89, Loss: 1.1895, Accuracy: 57.95%, Val Loss: 1.0857, Val Accuracy: 61.68%
# Epoch 90, Loss: 1.1881, Accuracy: 57.86%, Val Loss: 1.0650, Val Accuracy: 62.06%
# Epoch 91, Loss: 1.1875, Accuracy: 58.11%, Val Loss: 1.0691, Val Accuracy: 62.06%
# Epoch 92, Loss: 1.1847, Accuracy: 58.14%, Val Loss: 1.0678, Val Accuracy: 62.39%
# Epoch 93, Loss: 1.1858, Accuracy: 57.92%, Val Loss: 1.0642, Val Accuracy: 62.17%
# Epoch 94, Loss: 1.1855, Accuracy: 57.96%, Val Loss: 1.0652, Val Accuracy: 62.21%
# Epoch 95, Loss: 1.1788, Accuracy: 58.40%, Val Loss: 1.0673, Val Accuracy: 62.21%
# Epoch 96, Loss: 1.1747, Accuracy: 58.36%, Val Loss: 1.0570, Val Accuracy: 62.36%
# Epoch 97, Loss: 1.1732, Accuracy: 58.48%, Val Loss: 1.0594, Val Accuracy: 62.20%
# Epoch 98, Loss: 1.1698, Accuracy: 58.65%, Val Loss: 1.0670, Val Accuracy: 62.12%
# Epoch 99, Loss: 1.1665, Accuracy: 58.84%, Val Loss: 1.0612, Val Accuracy: 62.29%
# Epoch 100, Loss: 1.1655, Accuracy: 58.83%, Val Loss: 1.0543, Val Accuracy: 62.43%
# Epoch 101, Loss: 1.1636, Accuracy: 58.56%, Val Loss: 1.0518, Val Accuracy: 62.81%
# Epoch 102, Loss: 1.1649, Accuracy: 58.96%, Val Loss: 1.0555, Val Accuracy: 62.42%
# Epoch 103, Loss: 1.1577, Accuracy: 59.01%, Val Loss: 1.0466, Val Accuracy: 62.63%
# Epoch 104, Loss: 1.1607, Accuracy: 58.82%, Val Loss: 1.0519, Val Accuracy: 62.76%
# Epoch 105, Loss: 1.1567, Accuracy: 59.10%, Val Loss: 1.0464, Val Accuracy: 63.14%
# Epoch 106, Loss: 1.1540, Accuracy: 59.21%, Val Loss: 1.0475, Val Accuracy: 62.83%
# Epoch 107, Loss: 1.1589, Accuracy: 59.35%, Val Loss: 1.0415, Val Accuracy: 62.66%
# Epoch 108, Loss: 1.1494, Accuracy: 59.40%, Val Loss: 1.0402, Val Accuracy: 62.58%
# Epoch 109, Loss: 1.1552, Accuracy: 59.27%, Val Loss: 1.0446, Val Accuracy: 62.69%
# Epoch 110, Loss: 1.1559, Accuracy: 59.22%, Val Loss: 1.0393, Val Accuracy: 62.80%
# Epoch 111, Loss: 1.1542, Accuracy: 59.07%, Val Loss: 1.0443, Val Accuracy: 62.89%
# Epoch 112, Loss: 1.1475, Accuracy: 59.52%, Val Loss: 1.0444, Val Accuracy: 62.40%
# Epoch 113, Loss: 1.1461, Accuracy: 59.45%, Val Loss: 1.0413, Val Accuracy: 62.60%
# Epoch 114, Loss: 1.1469, Accuracy: 59.61%, Val Loss: 1.0338, Val Accuracy: 62.94%
# Epoch 115, Loss: 1.1426, Accuracy: 59.68%, Val Loss: 1.0416, Val Accuracy: 62.68%
# Epoch 116, Loss: 1.1447, Accuracy: 59.64%, Val Loss: 1.0380, Val Accuracy: 63.29%
# Epoch 117, Loss: 1.1410, Accuracy: 59.40%, Val Loss: 1.0318, Val Accuracy: 63.07%
# Epoch 118, Loss: 1.1361, Accuracy: 59.81%, Val Loss: 1.0319, Val Accuracy: 63.42%
# Epoch 119, Loss: 1.1343, Accuracy: 59.81%, Val Loss: 1.0318, Val Accuracy: 63.42%
# Epoch 120, Loss: 1.1386, Accuracy: 59.80%, Val Loss: 1.0320, Val Accuracy: 63.57%
# Epoch 121, Loss: 1.1321, Accuracy: 60.23%, Val Loss: 1.0297, Val Accuracy: 63.65%
# Epoch 122, Loss: 1.1317, Accuracy: 60.03%, Val Loss: 1.0195, Val Accuracy: 63.79%
# Epoch 123, Loss: 1.1319, Accuracy: 59.95%, Val Loss: 1.0301, Val Accuracy: 63.78%
# Epoch 124, Loss: 1.1259, Accuracy: 60.29%, Val Loss: 1.0349, Val Accuracy: 63.42%
# Epoch 125, Loss: 1.1251, Accuracy: 60.37%, Val Loss: 1.0294, Val Accuracy: 63.41%
# Epoch 126, Loss: 1.1274, Accuracy: 60.23%, Val Loss: 1.0293, Val Accuracy: 63.64%
# Epoch 127, Loss: 1.1308, Accuracy: 60.24%, Val Loss: 1.0204, Val Accuracy: 63.71%
# Epoch 128, Loss: 1.1247, Accuracy: 60.19%, Val Loss: 1.0187, Val Accuracy: 63.38%
# Epoch 129, Loss: 1.1243, Accuracy: 60.34%, Val Loss: 1.0316, Val Accuracy: 63.01%
# Epoch 130, Loss: 1.1244, Accuracy: 60.32%, Val Loss: 1.0188, Val Accuracy: 63.57%
# Epoch 131, Loss: 1.1217, Accuracy: 60.37%, Val Loss: 1.0193, Val Accuracy: 63.61%
# Epoch 132, Loss: 1.1181, Accuracy: 60.81%, Val Loss: 1.0320, Val Accuracy: 62.97%
# Epoch 133, Loss: 1.1159, Accuracy: 60.45%, Val Loss: 1.0254, Val Accuracy: 63.56%
# Epoch 134, Loss: 1.1126, Accuracy: 60.80%, Val Loss: 1.0236, Val Accuracy: 63.93%
# Epoch 135, Loss: 1.0973, Accuracy: 61.35%, Val Loss: 1.0073, Val Accuracy: 64.48%
# Epoch 136, Loss: 1.0963, Accuracy: 61.28%, Val Loss: 1.0013, Val Accuracy: 64.73%
# Epoch 137, Loss: 1.0817, Accuracy: 61.84%, Val Loss: 1.0023, Val Accuracy: 64.70%
# Epoch 138, Loss: 1.0861, Accuracy: 61.54%, Val Loss: 1.0030, Val Accuracy: 64.45%
# Epoch 139, Loss: 1.0779, Accuracy: 62.05%, Val Loss: 0.9988, Val Accuracy: 64.77%
# Epoch 140, Loss: 1.0739, Accuracy: 62.27%, Val Loss: 0.9966, Val Accuracy: 64.77%
# Epoch 141, Loss: 1.0678, Accuracy: 62.23%, Val Loss: 0.9946, Val Accuracy: 64.98%
# Epoch 142, Loss: 1.0697, Accuracy: 62.14%, Val Loss: 0.9956, Val Accuracy: 64.90%
# Epoch 143, Loss: 1.0675, Accuracy: 62.34%, Val Loss: 0.9952, Val Accuracy: 64.80%
# Epoch 144, Loss: 1.0646, Accuracy: 62.54%, Val Loss: 0.9956, Val Accuracy: 64.71%
# Epoch 145, Loss: 1.0618, Accuracy: 62.19%, Val Loss: 0.9928, Val Accuracy: 64.80%
# Epoch 146, Loss: 1.0572, Accuracy: 62.54%, Val Loss: 0.9952, Val Accuracy: 64.70%
# Epoch 147, Loss: 1.0610, Accuracy: 62.41%, Val Loss: 0.9929, Val Accuracy: 64.72%
# Epoch 148, Loss: 1.0561, Accuracy: 62.94%, Val Loss: 0.9910, Val Accuracy: 65.04%
# Epoch 149, Loss: 1.0618, Accuracy: 62.41%, Val Loss: 0.9906, Val Accuracy: 64.99%
# Epoch 150, Loss: 1.0552, Accuracy: 62.52%, Val Loss: 0.9924, Val Accuracy: 64.94%
# Evaluasi akhir model...
# Final Test Loss: 0.9924, Test Accuracy: 64.94%

# %% [markdown]
# ### 4. Mengevaluasi Model dengan Menghitung Akurasi, Presisi, Recall, F1Squared, ROC, dan AUC-ROC

# %%
# Mendapatkan semua prediksi untuk evaluasi metrik
y_true, y_pred, y_pred_proba = get_all_predictions(model_mlp, testloader)

# Menghitung metrik evaluasi
accuracy, precision, recall, f1, roc_auc = evaluate_metrics(y_true, y_pred, y_pred_proba)

# Output metrik evaluasi
print("\nMetrik Evaluasi MLP Model dengan PyTorch:")
print(f"Accuracy: {test_accuracy_mlp/100:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")
# Out:
# Metrik Evaluasi MLP Model dengan PyTorch:
# Accuracy: 0.6494
# Precision: 0.6477
# Recall: 0.6494
# F1 Score: 0.6466
# ROC AUC: 0.9415

# %% [markdown]
# ### 5. Memvisualisasikan Prediksi dari model yang telah dilatih

# %%
# Plot training history
visualize_results(train_losses_mlp, train_accuracies_mlp)

# Plot ROC curve (one vs rest untuk multi-kelas)
visualize_roc_curve(y_true, y_pred_proba)

# Plot confusion matrix
visualize_confusion_matrix(y_true, y_pred)

# %% [markdown]
# ### 6. Menyimpan Model

# %%
# Menyimpan model
torch.save(model_mlp.state_dict(), 'model_pytorch_cifar-10_mlp.pth')
print("Model disimpan sebagai 'model_pytorch_cifar-10_mlp.pth'")
# Out:
# Model disimpan sebagai 'model_pytorch_cifar-10_mlp.pth'

# %% [markdown]
# ## B. CNN CIFAR-10 dengan PyTorch

# %% [markdown]
# ### 1. Menyusun Model CNN Sederhana

# %%
# Mendefinisikan model CNN
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        # Blok konvolusi 1
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(32)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout1 = nn.Dropout(0.2)

        # Blok konvolusi 2
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(64)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout2 = nn.Dropout(0.2)

        # Blok konvolusi 3
        self.conv5 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn5 = nn.BatchNorm2d(128)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.bn6 = nn.BatchNorm2d(128)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout3 = nn.Dropout(0.25)

        # Fully connected layers
        self.fc1 = nn.Linear(128 * 4 * 4, 512)
        self.bn7 = nn.BatchNorm1d(512)
        self.dropout4 = nn.Dropout(0.4)
        self.fc2 = nn.Linear(512, len(classes))

    def forward(self, x):
        # Blok 1
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = self.pool1(x)
        x = self.dropout1(x)

        # Blok 2
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.bn4(self.conv4(x)))
        x = self.pool2(x)
        x = self.dropout2(x)

        # Blok 3
        x = F.relu(self.bn5(self.conv5(x)))
        x = F.relu(self.bn6(self.conv6(x)))
        x = self.pool3(x)
        x = self.dropout3(x)

        # Flatten
        x = x.view(-1, 128 * 4 * 4)

        # Fully connected
        x = F.relu(self.bn7(self.fc1(x)))
        x = self.dropout4(x)
        x = self.fc2(x)

        return x

model_cnn = CNN().to(device)
print(model_cnn)
# Out:
# CNN(
#   (conv1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout2): Dropout(p=0.25, inplace=False)
#   (conv5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout3): Dropout(p=0.25, inplace=False)
#   (fc1): Linear(in_features=2048, out_features=512, bias=True)
#   (bn7): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout4): Dropout(p=0.5, inplace=False)
#   (fc2): Linear(in_features=512, out_features=10, bias=True)
# )

# %% [markdown]
# ### 2. Menyiapkan Optimizer dan Loss Function

# %%
# Inisialisasi loss function dan optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_cnn.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.1, verbose=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %% [markdown]
# ### 3. Melatih Model

# %%
# Melatih model
print("Melatih model CNN...")
train_losses_cnn, train_accuracies_cnn, val_losses_cnn, val_accuracies_cnn = train_model(model_cnn, trainloader, criterion, optimizer, scheduler, epochs=100)

# Mengevaluasi model
print("Evaluasi akhir model...")
test_loss_cnn, test_accuracy_cnn = evaluate_model(model_cnn, testloader, criterion)
print(f"Final Test Loss: {test_loss_cnn:.4f}, Test Accuracy: {test_accuracy_cnn:.2f}%")
# Out:
# Melatih model CNN...
# Epoch 1, Loss: 1.4786, Accuracy: 45.96%, Val Loss: 1.1309, Val Accuracy: 59.23%
# Epoch 2, Loss: 1.0829, Accuracy: 61.14%, Val Loss: 1.0615, Val Accuracy: 63.26%
# Epoch 3, Loss: 0.9233, Accuracy: 67.17%, Val Loss: 0.8555, Val Accuracy: 70.19%
# Epoch 4, Loss: 0.8281, Accuracy: 70.74%, Val Loss: 0.7820, Val Accuracy: 73.12%
# Epoch 5, Loss: 0.7674, Accuracy: 73.06%, Val Loss: 0.7420, Val Accuracy: 73.70%
# Epoch 6, Loss: 0.7178, Accuracy: 74.71%, Val Loss: 0.6214, Val Accuracy: 78.33%
# Epoch 7, Loss: 0.6760, Accuracy: 76.30%, Val Loss: 0.5468, Val Accuracy: 81.30%
# Epoch 8, Loss: 0.6502, Accuracy: 77.22%, Val Loss: 0.5760, Val Accuracy: 80.26%
# Epoch 9, Loss: 0.6185, Accuracy: 78.66%, Val Loss: 0.5314, Val Accuracy: 81.76%
# Epoch 10, Loss: 0.5979, Accuracy: 79.25%, Val Loss: 0.5887, Val Accuracy: 79.70%
# Epoch 11, Loss: 0.5744, Accuracy: 80.02%, Val Loss: 0.5308, Val Accuracy: 81.28%
# Epoch 12, Loss: 0.5539, Accuracy: 80.77%, Val Loss: 0.4631, Val Accuracy: 84.31%
# Epoch 13, Loss: 0.5423, Accuracy: 81.32%, Val Loss: 0.5254, Val Accuracy: 81.78%
# Epoch 14, Loss: 0.5265, Accuracy: 81.83%, Val Loss: 0.4662, Val Accuracy: 83.91%
# Epoch 15, Loss: 0.5099, Accuracy: 82.26%, Val Loss: 0.5329, Val Accuracy: 82.23%
# Epoch 16, Loss: 0.4968, Accuracy: 82.72%, Val Loss: 0.4320, Val Accuracy: 85.06%
# Epoch 17, Loss: 0.4828, Accuracy: 83.30%, Val Loss: 0.4513, Val Accuracy: 84.53%
# Epoch 18, Loss: 0.4787, Accuracy: 83.38%, Val Loss: 0.4580, Val Accuracy: 84.69%
# Epoch 19, Loss: 0.4650, Accuracy: 83.94%, Val Loss: 0.4146, Val Accuracy: 86.12%
# Epoch 20, Loss: 0.4593, Accuracy: 84.09%, Val Loss: 0.4150, Val Accuracy: 85.52%
# Epoch 21, Loss: 0.4454, Accuracy: 84.57%, Val Loss: 0.4185, Val Accuracy: 85.57%
# Epoch 22, Loss: 0.4393, Accuracy: 84.81%, Val Loss: 0.3935, Val Accuracy: 86.97%
# Epoch 23, Loss: 0.4285, Accuracy: 85.09%, Val Loss: 0.4144, Val Accuracy: 85.55%
# Epoch 24, Loss: 0.4230, Accuracy: 85.43%, Val Loss: 0.4357, Val Accuracy: 85.33%
# Epoch 25, Loss: 0.4227, Accuracy: 85.24%, Val Loss: 0.4260, Val Accuracy: 85.87%
# Epoch 26, Loss: 0.4117, Accuracy: 85.68%, Val Loss: 0.4372, Val Accuracy: 85.61%
# Epoch 27, Loss: 0.4080, Accuracy: 85.71%, Val Loss: 0.4106, Val Accuracy: 86.46%
# Epoch 28, Loss: 0.4017, Accuracy: 86.12%, Val Loss: 0.3784, Val Accuracy: 87.69%
# Epoch 29, Loss: 0.3940, Accuracy: 86.24%, Val Loss: 0.3979, Val Accuracy: 87.04%
# Epoch 30, Loss: 0.3922, Accuracy: 86.56%, Val Loss: 0.4076, Val Accuracy: 86.50%
# Epoch 31, Loss: 0.3863, Accuracy: 86.46%, Val Loss: 0.3712, Val Accuracy: 87.38%
# Epoch 32, Loss: 0.3813, Accuracy: 86.66%, Val Loss: 0.3916, Val Accuracy: 87.00%
# Epoch 33, Loss: 0.3759, Accuracy: 87.02%, Val Loss: 0.4510, Val Accuracy: 85.37%
# Epoch 34, Loss: 0.3729, Accuracy: 87.08%, Val Loss: 0.3755, Val Accuracy: 87.71%
# Epoch 35, Loss: 0.3642, Accuracy: 87.24%, Val Loss: 0.4089, Val Accuracy: 86.48%
# Epoch 36, Loss: 0.3596, Accuracy: 87.42%, Val Loss: 0.3871, Val Accuracy: 86.91%
# Epoch 37, Loss: 0.3655, Accuracy: 87.12%, Val Loss: 0.3883, Val Accuracy: 87.41%
# Epoch 38, Loss: 0.3224, Accuracy: 88.62%, Val Loss: 0.3314, Val Accuracy: 89.14%
# Epoch 39, Loss: 0.3115, Accuracy: 89.10%, Val Loss: 0.3277, Val Accuracy: 89.12%
# Epoch 40, Loss: 0.3045, Accuracy: 89.34%, Val Loss: 0.3223, Val Accuracy: 89.28%
# Epoch 41, Loss: 0.2987, Accuracy: 89.56%, Val Loss: 0.3228, Val Accuracy: 89.27%
# Epoch 42, Loss: 0.2999, Accuracy: 89.55%, Val Loss: 0.3233, Val Accuracy: 89.29%
# Epoch 43, Loss: 0.2912, Accuracy: 89.67%, Val Loss: 0.3216, Val Accuracy: 89.46%
# Epoch 44, Loss: 0.2939, Accuracy: 89.74%, Val Loss: 0.3241, Val Accuracy: 89.53%
# Epoch 45, Loss: 0.2876, Accuracy: 89.85%, Val Loss: 0.3230, Val Accuracy: 89.44%
# Epoch 46, Loss: 0.2856, Accuracy: 89.98%, Val Loss: 0.3223, Val Accuracy: 89.49%
# Epoch 47, Loss: 0.2869, Accuracy: 89.89%, Val Loss: 0.3208, Val Accuracy: 89.64%
# Epoch 48, Loss: 0.2864, Accuracy: 89.85%, Val Loss: 0.3235, Val Accuracy: 89.51%
# Epoch 49, Loss: 0.2804, Accuracy: 90.27%, Val Loss: 0.3218, Val Accuracy: 89.47%
# Epoch 50, Loss: 0.2852, Accuracy: 90.10%, Val Loss: 0.3198, Val Accuracy: 89.54%
# Epoch 51, Loss: 0.2811, Accuracy: 90.18%, Val Loss: 0.3217, Val Accuracy: 89.51%
# Epoch 52, Loss: 0.2803, Accuracy: 90.29%, Val Loss: 0.3222, Val Accuracy: 89.61%
# Epoch 53, Loss: 0.2789, Accuracy: 90.34%, Val Loss: 0.3159, Val Accuracy: 89.89%
# Epoch 54, Loss: 0.2778, Accuracy: 90.21%, Val Loss: 0.3225, Val Accuracy: 89.54%
# Epoch 55, Loss: 0.2740, Accuracy: 90.35%, Val Loss: 0.3232, Val Accuracy: 89.31%
# Epoch 56, Loss: 0.2719, Accuracy: 90.50%, Val Loss: 0.3254, Val Accuracy: 89.69%
# Epoch 57, Loss: 0.2771, Accuracy: 90.27%, Val Loss: 0.3218, Val Accuracy: 89.62%
# Epoch 58, Loss: 0.2730, Accuracy: 90.41%, Val Loss: 0.3220, Val Accuracy: 89.66%
# Epoch 59, Loss: 0.2720, Accuracy: 90.37%, Val Loss: 0.3240, Val Accuracy: 89.63%
# Epoch 60, Loss: 0.2653, Accuracy: 90.75%, Val Loss: 0.3199, Val Accuracy: 89.67%
# Epoch 61, Loss: 0.2644, Accuracy: 90.62%, Val Loss: 0.3192, Val Accuracy: 89.64%
# Epoch 62, Loss: 0.2608, Accuracy: 90.78%, Val Loss: 0.3187, Val Accuracy: 89.67%
# Epoch 63, Loss: 0.2657, Accuracy: 90.65%, Val Loss: 0.3153, Val Accuracy: 89.57%
# Epoch 64, Loss: 0.2629, Accuracy: 90.60%, Val Loss: 0.3174, Val Accuracy: 89.63%
# Epoch 65, Loss: 0.2569, Accuracy: 91.08%, Val Loss: 0.3173, Val Accuracy: 89.61%
# Epoch 66, Loss: 0.2676, Accuracy: 90.71%, Val Loss: 0.3139, Val Accuracy: 89.72%
# Epoch 67, Loss: 0.2575, Accuracy: 90.95%, Val Loss: 0.3202, Val Accuracy: 89.56%
# Epoch 68, Loss: 0.2647, Accuracy: 90.84%, Val Loss: 0.3151, Val Accuracy: 89.63%
# Epoch 69, Loss: 0.2637, Accuracy: 90.85%, Val Loss: 0.3176, Val Accuracy: 89.72%
# Epoch 70, Loss: 0.2615, Accuracy: 90.81%, Val Loss: 0.3168, Val Accuracy: 89.67%
# Epoch 71, Loss: 0.2671, Accuracy: 90.59%, Val Loss: 0.3144, Val Accuracy: 89.63%
# Epoch 72, Loss: 0.2667, Accuracy: 90.78%, Val Loss: 0.3137, Val Accuracy: 89.68%
# Epoch 73, Loss: 0.2577, Accuracy: 91.03%, Val Loss: 0.3177, Val Accuracy: 89.55%
# Epoch 74, Loss: 0.2627, Accuracy: 90.68%, Val Loss: 0.3138, Val Accuracy: 89.80%
# Epoch 75, Loss: 0.2633, Accuracy: 90.72%, Val Loss: 0.3162, Val Accuracy: 89.71%
# Epoch 76, Loss: 0.2612, Accuracy: 90.91%, Val Loss: 0.3197, Val Accuracy: 89.84%
# Epoch 77, Loss: 0.2597, Accuracy: 90.88%, Val Loss: 0.3201, Val Accuracy: 89.67%
# Epoch 78, Loss: 0.2591, Accuracy: 90.90%, Val Loss: 0.3183, Val Accuracy: 89.68%
# Epoch 79, Loss: 0.2581, Accuracy: 90.86%, Val Loss: 0.3177, Val Accuracy: 89.82%
# Epoch 80, Loss: 0.2583, Accuracy: 90.96%, Val Loss: 0.3132, Val Accuracy: 89.73%
# Epoch 81, Loss: 0.2594, Accuracy: 90.92%, Val Loss: 0.3150, Val Accuracy: 89.81%
# Epoch 82, Loss: 0.2608, Accuracy: 90.85%, Val Loss: 0.3182, Val Accuracy: 89.64%
# Epoch 83, Loss: 0.2601, Accuracy: 90.82%, Val Loss: 0.3162, Val Accuracy: 89.69%
# Epoch 84, Loss: 0.2652, Accuracy: 90.76%, Val Loss: 0.3179, Val Accuracy: 89.65%
# Epoch 85, Loss: 0.2598, Accuracy: 90.87%, Val Loss: 0.3242, Val Accuracy: 89.70%
# Epoch 86, Loss: 0.2627, Accuracy: 90.65%, Val Loss: 0.3186, Val Accuracy: 89.67%
# Epoch 87, Loss: 0.2577, Accuracy: 90.92%, Val Loss: 0.3191, Val Accuracy: 89.73%
# Epoch 88, Loss: 0.2611, Accuracy: 90.94%, Val Loss: 0.3163, Val Accuracy: 89.75%
# Epoch 89, Loss: 0.2582, Accuracy: 90.87%, Val Loss: 0.3175, Val Accuracy: 89.73%
# Epoch 90, Loss: 0.2573, Accuracy: 90.93%, Val Loss: 0.3152, Val Accuracy: 89.69%
# Epoch 91, Loss: 0.2607, Accuracy: 90.84%, Val Loss: 0.3197, Val Accuracy: 89.75%
# Epoch 92, Loss: 0.2617, Accuracy: 90.85%, Val Loss: 0.3173, Val Accuracy: 89.68%
# Epoch 93, Loss: 0.2563, Accuracy: 90.90%, Val Loss: 0.3160, Val Accuracy: 89.78%
# Epoch 94, Loss: 0.2591, Accuracy: 90.92%, Val Loss: 0.3139, Val Accuracy: 89.78%
# Epoch 95, Loss: 0.2611, Accuracy: 90.80%, Val Loss: 0.3151, Val Accuracy: 89.74%
# Epoch 96, Loss: 0.2582, Accuracy: 91.00%, Val Loss: 0.3182, Val Accuracy: 89.75%
# Epoch 97, Loss: 0.2583, Accuracy: 90.89%, Val Loss: 0.3152, Val Accuracy: 89.77%
# Epoch 98, Loss: 0.2645, Accuracy: 90.68%, Val Loss: 0.3167, Val Accuracy: 89.68%
# Epoch 99, Loss: 0.2584, Accuracy: 90.98%, Val Loss: 0.3158, Val Accuracy: 89.70%
# Epoch 100, Loss: 0.2620, Accuracy: 90.76%, Val Loss: 0.3193, Val Accuracy: 89.68%
# Evaluasi akhir model...
# Final Test Loss: 0.3193, Test Accuracy: 89.68%

# %% [markdown]
# ### 4. Mengevaluasi Model dengan Menghitung Akurasi, Presisi, Recall, F1Squared, ROC, dan AUC-ROC

# %%
# Mendapatkan semua prediksi untuk evaluasi metrik
y_true, y_pred, y_pred_proba = get_all_predictions(model_cnn, testloader)

# Menghitung metrik evaluasi
accuracy, precision, recall, f1, roc_auc = evaluate_metrics(y_true, y_pred, y_pred_proba)

# Output metrik evaluasi
print("\nMetrik Evaluasi CNN Model dengan PyTorch:")
print(f"Accuracy: {test_accuracy_cnn/100:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")
# Out:
# Metrik Evaluasi CNN Model dengan PyTorch:
# Accuracy: 0.8968
# Precision: 0.8965
# Recall: 0.8968
# F1 Score: 0.8957
# ROC AUC: 0.9937

# %% [markdown]
# ### 5. Memvisualisasikan Prediksi dari model yang telah dilatih

# %%
# Plot training history
visualize_results(train_losses_cnn, train_accuracies_cnn)

# Plot ROC curve (one vs rest untuk multi-kelas)
visualize_roc_curve(y_true, y_pred_proba)

# Plot confusion matrix
visualize_confusion_matrix(y_true, y_pred)

# %% [markdown]
# ### 6. Menyimpan Model

# %%
# Menyimpan model
torch.save(model_cnn.state_dict(), 'model_pytorch_cifar-10_cnn.pth')
print("Model disimpan sebagai 'model_pytorch_cifar-10_cnn.pth'")
# Out:
# Model disimpan sebagai 'model_pytorch_cifar-10_cnn.pth'

# %% [markdown]
# # Deep Learning dengan TensorFlow (MLP dan CNN)

# %% [markdown]
# ### 1. Import Library yang Dibutuhkan

# %%
import tensorflow as tf # Library utama untuk deep learning
import tensorflow_datasets as tfds # Library untuk dataset
import numpy as np # Library untuk manipulasi array
from sklearn.preprocessing import label_binarize
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, roc_curve, auc, confusion_matrix # Library untuk metrik evaluasi
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization # Library untuk layer-layer CNN
from tensorflow.keras.models import Sequential # Library untuk model sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau # Library untuk callbacks
from tensorflow.keras.optimizers import Adam # Library untuk optimizers

# %% [markdown]
# ### 2. Mendefinisikan Transformasi Data dan Memuat Dataset CIFAR-10

# %%
# Memuat dataset CIFAR-10
(ds_train, ds_test), ds_info = tfds.load(
    'cifar10', # Dataset CIFAR-10
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)

# Fungsi preprocessing
def normalize_img(image, label):
    """Normalisasi gambar: `uint8` -> `float32`."""
    return tf.cast(image, tf.float32) / 255., label

# Mengatur alur data untuk training
BATCH_SIZE = 64
ds_train = ds_train.map(normalize_img)
ds_train = ds_train.cache()
ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples)
ds_train = ds_train.batch(BATCH_SIZE)
ds_train = ds_train.prefetch(tf.data.experimental.AUTOTUNE)

# Mengatur alur data untuk testing
ds_test = ds_test.map(normalize_img)
ds_test = ds_test.batch(BATCH_SIZE)
ds_test = ds_test.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/cifar10/3.0.2 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/cifar10/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/cifar10/incomplete.4BVXDD_3.0.2/cifar10-train.tfrecord*...:   0%|         …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/cifar10/incomplete.4BVXDD_3.0.2/cifar10-test.tfrecord*...:   0%|          …
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %% [markdown]
# ### 5. Menyiapkan Fungsi Evaluasi

# %%
def evaluate_metrics(y_true, y_pred, y_prob):
    y_true_one_hot = tf.keras.utils.to_categorical(y_true, num_classes=10)

    # Menghitung metrik evaluasi
    precision = precision_score(y_true, y_pred, average='macro')
    recall = recall_score(y_true, y_pred, average='macro')
    f1 = f1_score(y_true, y_pred, average='macro')
    roc_auc = roc_auc_score(y_true_one_hot, y_prob, average='macro', multi_class='ovr')

    return precision, recall, f1, roc_auc

# %% [markdown]
# ### 6. Menyiapkan Fungsi Visualisasi

# %%
def visualize_results(history):
    # Plot training history
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.tight_layout()
    plt.show()

# Fungsi untuk menampilkan ROC curve
def visualize_roc_curve(y_true, y_scores):
    # Binarize the output
    n_classes = y_scores.shape[1]
    y_true_bin = label_binarize(y_true, classes=np.arange(n_classes))

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_scores[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y_true_bin.ravel(), y_scores.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

    # Plot ROC curve for a specific class (e.g., class 1)
    plt.figure(figsize=(8, 6))
    plt.plot(fpr[1], tpr[1], label=f'ROC curve (area = {roc_auc[1]:.2f})')  # Example: Plotting for class 1
    plt.plot([0, 1], [0, 1], 'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.show()

def visualize_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    plt.matshow(cm, cmap='Blues')
    plt.colorbar()
    plt.title('Confusion Matrix')

    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, f'{cm[i, j] / cm.sum() * 100:.1f}%', ha='center', va='bottom', color='lavender' if cm[i, j] > cm.max() / 2 else 'black')

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %% [markdown]
# ## A. MLP CIFAR-10 Dengan Tensorflow

# %% [markdown]
# ### 1. Penyusunan Model Neural Network

# %%
# Membuat model MLP
def create_mlp_model():
    model = Sequential([
        Input(shape=(32, 32, 3)),  # Input layer

        # Flattening input gambar 32x32x3 menjadi 3072 fitur
        Flatten(),

        # Layer hidden 1
        Dense(2048, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        # Layer hidden 2
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.33),

        # Layer hidden 3
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),

        # Layer output
        Dense(10, activation='softmax')  # 10 kelas untuk CIFAR-10
    ])

    return model

# Inisialisasi model
mlp_model = create_mlp_model()

# %% [markdown]
# ### 2. Kompilasi Model

# %%
# Kompilasi model
mlp_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ### 3. Pelatihan Model

# %%
# Callbacks untuk training
# Menghentikan pelatihan lebih awal jika tidak ada peningkatan dalam 15 epoch
callbacks = [
    EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
]

# Melatih model
history_mlp = mlp_model.fit(
    ds_train,
    epochs=100,
    validation_data=ds_test,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - accuracy: 0.2547 - loss: 2.3460 - val_accuracy: 0.3579 - val_loss: 1.7716 - learning_rate: 0.0010
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.3797 - loss: 1.7372 - val_accuracy: 0.3816 - val_loss: 1.7228 - learning_rate: 0.0010
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4052 - loss: 1.6695 - val_accuracy: 0.3492 - val_loss: 1.7836 - learning_rate: 0.0010
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4180 - loss: 1.6398 - val_accuracy: 0.4227 - val_loss: 1.6219 - learning_rate: 0.0010
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4238 - loss: 1.6153 - val_accuracy: 0.4275 - val_loss: 1.5963 - learning_rate: 0.0010
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4310 - loss: 1.5933 - val_accuracy: 0.4346 - val_loss: 1.5794 - learning_rate: 0.0010
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4395 - loss: 1.5758 - val_accuracy: 0.4641 - val_loss: 1.5192 - learning_rate: 0.0010
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4451 - loss: 1.5485 - val_accuracy: 0.2948 - val_loss: 1.9593 - learning_rate: 0.0010
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4444 - loss: 1.5590 - val_accuracy: 0.4763 - val_loss: 1.4637 - learning_rate: 0.0010
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4518 - loss: 1.5365 - val_accuracy: 0.4764 - val_loss: 1.4677 - learning_rate: 0.0010
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4586 - loss: 1.5236 - val_accuracy: 0.4774 - val_loss: 1.4733 - learning_rate: 0.0010
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4618 - loss: 1.5110 - val_accuracy: 0.4622 - val_loss: 1.4979 - learning_rate: 0.0010
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4702 - loss: 1.4950 - val_accuracy: 0.4796 - val_loss: 1.4328 - learning_rate: 0.0010
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4692 - loss: 1.4933 - val_accuracy: 0.4774 - val_loss: 1.4483 - learning_rate: 0.0010
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4700 - loss: 1.4858 - val_accuracy: 0.4852 - val_loss: 1.4601 - learning_rate: 0.0010
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4744 - loss: 1.4814 - val_accuracy: 0.4873 - val_loss: 1.4464 - learning_rate: 0.0010
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4780 - loss: 1.4688 - val_accuracy: 0.4839 - val_loss: 1.4363 - learning_rate: 0.0010
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4826 - loss: 1.4622 - val_accuracy: 0.4851 - val_loss: 1.4302 - learning_rate: 0.0010
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4771 - loss: 1.4667 - val_accuracy: 0.5011 - val_loss: 1.3899 - learning_rate: 0.0010
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4841 - loss: 1.4537 - val_accuracy: 0.4779 - val_loss: 1.4543 - learning_rate: 0.0010
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4808 - loss: 1.4563 - val_accuracy: 0.4876 - val_loss: 1.4419 - learning_rate: 0.0010
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4875 - loss: 1.4389 - val_accuracy: 0.5154 - val_loss: 1.3645 - learning_rate: 0.0010
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4850 - loss: 1.4312 - val_accuracy: 0.5196 - val_loss: 1.3572 - learning_rate: 0.0010
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4888 - loss: 1.4331 - val_accuracy: 0.5123 - val_loss: 1.3718 - learning_rate: 0.0010
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4885 - loss: 1.4380 - val_accuracy: 0.5006 - val_loss: 1.4071 - learning_rate: 0.0010
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4994 - loss: 1.4195 - val_accuracy: 0.5112 - val_loss: 1.3615 - learning_rate: 0.0010
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4951 - loss: 1.4277 - val_accuracy: 0.5031 - val_loss: 1.4091 - learning_rate: 0.0010
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4952 - loss: 1.4346 - val_accuracy: 0.4939 - val_loss: 1.4180 - learning_rate: 0.0010
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4994 - loss: 1.4078 - val_accuracy: 0.5290 - val_loss: 1.3269 - learning_rate: 2.0000e-04
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5018 - loss: 1.3970 - val_accuracy: 0.5326 - val_loss: 1.3093 - learning_rate: 2.0000e-04
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5107 - loss: 1.3781 - val_accuracy: 0.5327 - val_loss: 1.3093 - learning_rate: 2.0000e-04
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5056 - loss: 1.3957 - val_accuracy: 0.5363 - val_loss: 1.3037 - learning_rate: 2.0000e-04
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5118 - loss: 1.3782 - val_accuracy: 0.5336 - val_loss: 1.3100 - learning_rate: 2.0000e-04
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5104 - loss: 1.3774 - val_accuracy: 0.5368 - val_loss: 1.3069 - learning_rate: 2.0000e-04
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.5154 - loss: 1.3742 - val_accuracy: 0.5325 - val_loss: 1.3059 - learning_rate: 2.0000e-04
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5177 - loss: 1.3590 - val_accuracy: 0.5277 - val_loss: 1.3141 - learning_rate: 2.0000e-04
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5207 - loss: 1.3567 - val_accuracy: 0.5352 - val_loss: 1.2994 - learning_rate: 2.0000e-04
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5168 - loss: 1.3585 - val_accuracy: 0.5352 - val_loss: 1.3077 - learning_rate: 2.0000e-04
# Epoch 39/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5216 - loss: 1.3495 - val_accuracy: 0.5353 - val_loss: 1.2956 - learning_rate: 2.0000e-04
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5229 - loss: 1.3496 - val_accuracy: 0.5367 - val_loss: 1.2965 - learning_rate: 2.0000e-04
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5203 - loss: 1.3511 - val_accuracy: 0.5360 - val_loss: 1.2904 - learning_rate: 2.0000e-04
# Epoch 42/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5230 - loss: 1.3465 - val_accuracy: 0.5396 - val_loss: 1.2876 - learning_rate: 2.0000e-04
# Epoch 43/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5195 - loss: 1.3455 - val_accuracy: 0.5320 - val_loss: 1.3071 - learning_rate: 2.0000e-04
# Epoch 44/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5219 - loss: 1.3456 - val_accuracy: 0.5336 - val_loss: 1.3016 - learning_rate: 2.0000e-04
# Epoch 45/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5207 - loss: 1.3502 - val_accuracy: 0.5354 - val_loss: 1.2899 - learning_rate: 2.0000e-04
# Epoch 46/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5256 - loss: 1.3363 - val_accuracy: 0.5371 - val_loss: 1.2952 - learning_rate: 2.0000e-04
# Epoch 47/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5266 - loss: 1.3308 - val_accuracy: 0.5393 - val_loss: 1.2889 - learning_rate: 2.0000e-04
# Epoch 48/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5265 - loss: 1.3406 - val_accuracy: 0.5418 - val_loss: 1.2811 - learning_rate: 4.0000e-05
# Epoch 49/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5327 - loss: 1.3204 - val_accuracy: 0.5372 - val_loss: 1.2834 - learning_rate: 4.0000e-05
# Epoch 50/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5284 - loss: 1.3280 - val_accuracy: 0.5408 - val_loss: 1.2809 - learning_rate: 4.0000e-05
# Epoch 51/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5262 - loss: 1.3303 - val_accuracy: 0.5414 - val_loss: 1.2791 - learning_rate: 4.0000e-05
# Epoch 52/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5275 - loss: 1.3304 - val_accuracy: 0.5382 - val_loss: 1.2803 - learning_rate: 4.0000e-05
# Epoch 53/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5301 - loss: 1.3286 - val_accuracy: 0.5395 - val_loss: 1.2798 - learning_rate: 4.0000e-05
# Epoch 54/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5260 - loss: 1.3263 - val_accuracy: 0.5392 - val_loss: 1.2796 - learning_rate: 4.0000e-05
# Epoch 55/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5275 - loss: 1.3297 - val_accuracy: 0.5416 - val_loss: 1.2802 - learning_rate: 4.0000e-05
# Epoch 56/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5262 - loss: 1.3294 - val_accuracy: 0.5404 - val_loss: 1.2739 - learning_rate: 4.0000e-05
# Epoch 57/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5310 - loss: 1.3265 - val_accuracy: 0.5422 - val_loss: 1.2765 - learning_rate: 4.0000e-05
# Epoch 58/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5259 - loss: 1.3309 - val_accuracy: 0.5388 - val_loss: 1.2790 - learning_rate: 4.0000e-05
# Epoch 59/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5308 - loss: 1.3200 - val_accuracy: 0.5418 - val_loss: 1.2746 - learning_rate: 4.0000e-05
# Epoch 60/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5327 - loss: 1.3243 - val_accuracy: 0.5397 - val_loss: 1.2776 - learning_rate: 4.0000e-05
# Epoch 61/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5314 - loss: 1.3267 - val_accuracy: 0.5406 - val_loss: 1.2776 - learning_rate: 4.0000e-05
# Epoch 62/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5291 - loss: 1.3241 - val_accuracy: 0.5403 - val_loss: 1.2759 - learning_rate: 8.0000e-06
# Epoch 63/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5354 - loss: 1.3159 - val_accuracy: 0.5411 - val_loss: 1.2773 - learning_rate: 8.0000e-06
# Epoch 64/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5313 - loss: 1.3214 - val_accuracy: 0.5410 - val_loss: 1.2755 - learning_rate: 8.0000e-06
# Epoch 65/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5332 - loss: 1.3151 - val_accuracy: 0.5414 - val_loss: 1.2764 - learning_rate: 8.0000e-06
# Epoch 66/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5319 - loss: 1.3199 - val_accuracy: 0.5420 - val_loss: 1.2743 - learning_rate: 8.0000e-06
# Epoch 67/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5318 - loss: 1.3298 - val_accuracy: 0.5423 - val_loss: 1.2743 - learning_rate: 1.6000e-06
# Epoch 68/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5309 - loss: 1.3088 - val_accuracy: 0.5418 - val_loss: 1.2735 - learning_rate: 1.6000e-06
# Epoch 69/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5287 - loss: 1.3208 - val_accuracy: 0.5417 - val_loss: 1.2760 - learning_rate: 1.6000e-06
# Epoch 70/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5305 - loss: 1.3170 - val_accuracy: 0.5425 - val_loss: 1.2748 - learning_rate: 1.6000e-06
# Epoch 71/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5324 - loss: 1.3300 - val_accuracy: 0.5417 - val_loss: 1.2762 - learning_rate: 1.6000e-06
# Epoch 72/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5336 - loss: 1.3221 - val_accuracy: 0.5423 - val_loss: 1.2752 - learning_rate: 1.6000e-06
# Epoch 73/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5316 - loss: 1.3230 - val_accuracy: 0.5419 - val_loss: 1.2744 - learning_rate: 1.6000e-06
# Epoch 74/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5359 - loss: 1.3168 - val_accuracy: 0.5412 - val_loss: 1.2750 - learning_rate: 1.0000e-06
# Epoch 75/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5430 - loss: 1.3104 - val_accuracy: 0.5423 - val_loss: 1.2744 - learning_rate: 1.0000e-06
# Epoch 76/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5294 - loss: 1.3234 - val_accuracy: 0.5418 - val_loss: 1.2752 - learning_rate: 1.0000e-06
# Epoch 77/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5356 - loss: 1.3160 - val_accuracy: 0.5416 - val_loss: 1.2744 - learning_rate: 1.0000e-06
# Epoch 78/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5301 - loss: 1.3217 - val_accuracy: 0.5419 - val_loss: 1.2743 - learning_rate: 1.0000e-06
# Epoch 79/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5285 - loss: 1.3251 - val_accuracy: 0.5421 - val_loss: 1.2750 - learning_rate: 1.0000e-06
# Epoch 80/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5321 - loss: 1.3194 - val_accuracy: 0.5414 - val_loss: 1.2763 - learning_rate: 1.0000e-06
# Epoch 81/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5282 - loss: 1.3220 - val_accuracy: 0.5419 - val_loss: 1.2744 - learning_rate: 1.0000e-06
# Epoch 82/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5309 - loss: 1.3133 - val_accuracy: 0.5421 - val_loss: 1.2741 - learning_rate: 1.0000e-06
# Epoch 83/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5293 - loss: 1.3217 - val_accuracy: 0.5420 - val_loss: 1.2753 - learning_rate: 1.0000e-06

# %% [markdown]
# ### 4. Mengevaluasi Model dengan Menghitung Akurasi, Presisi, Recall, F1Squared, ROC, dan AUC-ROC

# %%
# Evaluasi model
test_loss, test_accuracy = mlp_model.evaluate(ds_test)
print(f"Test accuracy: {test_accuracy:.4f}")

# Konversi dataset untuk evaluasi metrik lengkap
y_true = []
y_pred = []
y_pred_proba = []

for images, labels in ds_test:
    predictions = mlp_model.predict(images)
    y_pred_proba.extend(predictions)
    y_pred.extend(np.argmax(predictions, axis=1))
    y_true.extend(labels.numpy())

y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_pred_proba = np.array(y_pred_proba)

# Menghitung metrik evaluasi
precision, recall, f1, roc_auc = evaluate_metrics(y_true, y_pred, y_pred_proba)

# Output metrik evaluasi
print("\nMetrik Evaluasi MLP Model dengan TensorFlow:")
print(f"Accuracy: {test_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5461 - loss: 1.2589
# Test accuracy: 0.5418
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#
# Metrik Evaluasi MLP Model dengan TensorFlow:
# Accuracy: 0.5418
# Precision: 0.5399
# Recall: 0.5418
# F1 Score: 0.5383
# ROC AUC: 0.9039

# %% [markdown]
# ### 5. Memvisualisasikan Prediksi dari model yang telah dilatih

# %%
# Plot training history
visualize_results(history_mlp)

# Plot ROC curve (one vs rest untuk multi-kelas)
visualize_roc_curve(y_true, y_pred_proba)

# Plot confusion matrix
visualize_confusion_matrix(y_true, y_pred)

# %% [markdown]
# ### 6. Menyimpan Model

# %%
# Menyimpan model
mlp_model.save('model_tensorflow_cifar-10_mlp.keras')
print("Model disimpan sebagai 'model_tensorflow_cifar-10_mlp.keras'")
# Out:
# Model disimpan sebagai 'model_tensorflow_cifar-10_mlp.keras'

# %% [markdown]
# ## B. CNN CIFAR-10 Dengan Tensorflow

# %% [markdown]
# ### 1. Penyusunan Model Neural Network

# %%
# Membuat model CNN
def create_cnn_model():
    model = Sequential([
        Input(shape=(32, 32, 3)),  # Input layer

        # Blok Konvolusional 1
        Conv2D(32, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        Conv2D(32, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.25),

        # Blok Konvolusional 2
        Conv2D(64, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        Conv2D(64, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.33),

        # Blok Konvolusional 3
        Conv2D(128, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        Conv2D(128, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.5),

        # Blok Konvolusional 4
        Conv2D(256, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        Conv2D(256, (3, 3), padding='same', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.5),

        # Fully connected layers
        Flatten(),
        Dense(512, activation='relu'),
        BatchNormalization(),
        Dropout(0.5),
        Dense(10, activation='softmax')  # 10 kelas untuk CIFAR-10
    ])

    return model

# Inisialisasi model
cnn_model = create_cnn_model()

# %% [markdown]
# ### 2. Kompilasi Model

# %%
# Kompilasi model
cnn_model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ### 3. Pelatihan Model

# %%
# Callbacks untuk training
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
]

# Melatih model
history_cnn = cnn_model.fit(
    ds_train,
    epochs=100,
    validation_data=ds_test,
    callbacks=callbacks
)
# Out:
# Epoch 1/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 30s 16ms/step - accuracy: 0.3079 - loss: 2.2320 - val_accuracy: 0.5275 - val_loss: 1.3668 - learning_rate: 0.0010
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5551 - loss: 1.2547 - val_accuracy: 0.5308 - val_loss: 1.4475 - learning_rate: 0.0010
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6515 - loss: 0.9955 - val_accuracy: 0.5817 - val_loss: 1.3332 - learning_rate: 0.0010
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7008 - loss: 0.8608 - val_accuracy: 0.7275 - val_loss: 0.8085 - learning_rate: 0.0010
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7356 - loss: 0.7559 - val_accuracy: 0.7467 - val_loss: 0.7283 - learning_rate: 0.0010
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7595 - loss: 0.6945 - val_accuracy: 0.7925 - val_loss: 0.5966 - learning_rate: 0.0010
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7806 - loss: 0.6405 - val_accuracy: 0.8018 - val_loss: 0.5755 - learning_rate: 0.0010
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7946 - loss: 0.5966 - val_accuracy: 0.8021 - val_loss: 0.5804 - learning_rate: 0.0010
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8087 - loss: 0.5570 - val_accuracy: 0.8041 - val_loss: 0.5797 - learning_rate: 0.0010
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8174 - loss: 0.5304 - val_accuracy: 0.8040 - val_loss: 0.5778 - learning_rate: 0.0010
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8301 - loss: 0.4994 - val_accuracy: 0.7929 - val_loss: 0.6117 - learning_rate: 0.0010
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8359 - loss: 0.4747 - val_accuracy: 0.8423 - val_loss: 0.4728 - learning_rate: 0.0010
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8469 - loss: 0.4446 - val_accuracy: 0.8293 - val_loss: 0.5147 - learning_rate: 0.0010
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8556 - loss: 0.4228 - val_accuracy: 0.8395 - val_loss: 0.4876 - learning_rate: 0.0010
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8561 - loss: 0.4184 - val_accuracy: 0.8233 - val_loss: 0.5420 - learning_rate: 0.0010
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8624 - loss: 0.3981 - val_accuracy: 0.8431 - val_loss: 0.4802 - learning_rate: 0.0010
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8657 - loss: 0.3884 - val_accuracy: 0.8507 - val_loss: 0.4485 - learning_rate: 0.0010
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8736 - loss: 0.3710 - val_accuracy: 0.8455 - val_loss: 0.4759 - learning_rate: 0.0010
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8754 - loss: 0.3583 - val_accuracy: 0.8542 - val_loss: 0.4453 - learning_rate: 0.0010
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8810 - loss: 0.3461 - val_accuracy: 0.8623 - val_loss: 0.4349 - learning_rate: 0.0010
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8852 - loss: 0.3320 - val_accuracy: 0.8619 - val_loss: 0.4362 - learning_rate: 0.0010
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8875 - loss: 0.3223 - val_accuracy: 0.8571 - val_loss: 0.4507 - learning_rate: 0.0010
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8936 - loss: 0.3038 - val_accuracy: 0.8531 - val_loss: 0.4916 - learning_rate: 0.0010
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8941 - loss: 0.3058 - val_accuracy: 0.8577 - val_loss: 0.4528 - learning_rate: 0.0010
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8952 - loss: 0.3010 - val_accuracy: 0.8646 - val_loss: 0.4240 - learning_rate: 0.0010
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9012 - loss: 0.2840 - val_accuracy: 0.8588 - val_loss: 0.4480 - learning_rate: 0.0010
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9047 - loss: 0.2783 - val_accuracy: 0.8467 - val_loss: 0.4867 - learning_rate: 0.0010
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9054 - loss: 0.2671 - val_accuracy: 0.8620 - val_loss: 0.4370 - learning_rate: 0.0010
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9105 - loss: 0.2604 - val_accuracy: 0.8564 - val_loss: 0.4480 - learning_rate: 0.0010
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9097 - loss: 0.2585 - val_accuracy: 0.8644 - val_loss: 0.4313 - learning_rate: 0.0010
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9222 - loss: 0.2271 - val_accuracy: 0.8782 - val_loss: 0.3800 - learning_rate: 2.0000e-04
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9308 - loss: 0.1975 - val_accuracy: 0.8790 - val_loss: 0.3899 - learning_rate: 2.0000e-04
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9338 - loss: 0.1882 - val_accuracy: 0.8810 - val_loss: 0.3918 - learning_rate: 2.0000e-04
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9356 - loss: 0.1784 - val_accuracy: 0.8856 - val_loss: 0.3917 - learning_rate: 2.0000e-04
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9377 - loss: 0.1770 - val_accuracy: 0.8807 - val_loss: 0.3924 - learning_rate: 2.0000e-04
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9408 - loss: 0.1678 - val_accuracy: 0.8844 - val_loss: 0.3906 - learning_rate: 2.0000e-04
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9452 - loss: 0.1550 - val_accuracy: 0.8845 - val_loss: 0.3898 - learning_rate: 4.0000e-05
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9446 - loss: 0.1597 - val_accuracy: 0.8846 - val_loss: 0.3884 - learning_rate: 4.0000e-05
# Epoch 39/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9443 - loss: 0.1571 - val_accuracy: 0.8845 - val_loss: 0.3926 - learning_rate: 4.0000e-05
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9464 - loss: 0.1502 - val_accuracy: 0.8846 - val_loss: 0.3931 - learning_rate: 4.0000e-05
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9476 - loss: 0.1484 - val_accuracy: 0.8847 - val_loss: 0.3930 - learning_rate: 4.0000e-05

# %% [markdown]
# ### 4. Mengevaluasi Model dengan Menghitung Akurasi, Presisi, Recall, F1Squared, ROC, dan AUC-ROC

# %%
# Evaluasi model
test_loss, test_accuracy = cnn_model.evaluate(ds_test)
print(f"Test accuracy: {test_accuracy:.4f}")

# Konversi dataset untuk evaluasi metrik lengkap
y_true = []
y_pred = []
y_pred_proba = []

# Menghitung prediksi untuk semua data uji
for images, labels in ds_test:
    predictions = cnn_model.predict(images)
    y_pred_proba.extend(predictions)
    y_pred.extend(np.argmax(predictions, axis=1))
    y_true.extend(labels.numpy())

# Mengonversi ke numpy array
y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_pred_proba = np.array(y_pred_proba)

# Menghitung metrik evaluasi
precision, recall, f1, roc_auc = evaluate_metrics(y_true, y_pred, y_pred_proba)

# Output metrik evaluasi
print("\nMetrik Evaluasi CNN Model dengan TensorFlow:")
print(f"Accuracy: {test_accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"ROC AUC: {roc_auc:.4f}")
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8820 - loss: 0.3624
# Test accuracy: 0.8782
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 774ms/step
#
# Metrik Evaluasi CNN Model dengan TensorFlow:
# Accuracy: 0.8782
# Precision: 0.8783
# Recall: 0.8782
# F1 Score: 0.8780
# ROC AUC: 0.9917

# %% [markdown]
# ### 5. Memvisualisasikan Prediksi dari model yang telah dilatih

# %%
# Plot training history
visualize_results(history_cnn)

# Plot ROC curve (one vs rest untuk multi-kelas)
visualize_roc_curve(y_true, y_pred_proba)

# Plot confusion matrix
visualize_confusion_matrix(y_true, y_pred)

# %% [markdown]
# ### 6. Menyimpan Model

# %%
# Menyimpan model
cnn_model.save('model_tensorflow_cifar-10_cnn.keras')
print("Model disimpan sebagai 'model_tensorflow_cifar-10_cnn.keras'")
# Out:
# Model disimpan sebagai 'model_tensorflow_cifar-10_cnn.keras'

# %% [markdown]
# Penjelasan Persamaan Matematika dalam Model MLP dan CNN
#
# ## 1. Konvolusi (Convolution)
# Dalam model CNN, operasi konvolusi adalah operasi dasar yang menjadi inti dari arsitektur. Secara matematis, konvolusi 2D dapat didefinisikan sebagai:
#
# $$(I * K)(i, j) = \sum_{m} \sum_{n} I(i-m, j-n) \cdot K(m, n)$$
#
# dimana:
# - $I$ adalah citra input
# - $K$ adalah kernel atau filter
# - $*$ adalah operator konvolusi
# - $i, j$ adalah indeks piksel output
# - $m, n$ adalah indeks kernel
#
# Konvolusi bekerja dengan menggeser kernel di atas citra input, mengalikan nilai-nilai yang bertumpuk, dan menjumlahkan hasil untuk menghasilkan piksel output.
#
# ## 2. Aktivasi ReLU (Rectified Linear Unit)
#
# Fungsi aktivasi ReLU yang digunakan dalam model kita didefinisikan sebagai:
#
# $$f(x) = \max(0, x)$$
#
# ReLU akan mengubah semua nilai negatif menjadi 0, sementara nilai positif tetap tidak berubah. Ini membantu model untuk belajar fungsi non-linear dan mengatasi masalah vanishing gradient.
#
# ## 3. Batch Normalization
#
# Batch Normalization digunakan untuk menstabilkan dan mempercepat proses pembelajaran dengan menormalkan aktivasi di setiap lapisan. Rumus matematisnya adalah:
#
# $$\hat{x}_i = \frac{x_i - \mu_B}{\sqrt{\sigma_B^2 + \epsilon}}​$$
#
# $$y_i = \gamma \cdot \hat{x}_i + \beta$$
#
# dimana:
# - $x_i$ adalah input ke batch normalization
# - $\mu_B$ adalah rata-rata mini-batch
# - $\sigma_B^2$ adalah varians mini-batch
# - $\epsilon$ adalah konstanta kecil untuk stabilitas numerik
# - $\gamma$ dan $\beta$ adalah parameter yang dipelajari
# - $y_i$ adalah output batch normalization
#
# ## 4. Max Pooling
#
# Max Pooling digunakan untuk mengurangi dimensi spasial dengan memilih nilai maksimum dari setiap region. Secara matematis:
#
# $$\text{MaxPool}(X)_{i,j} = \max_{m,n \in R_{i,j}} X_{m,n}​$$
#
# dimana $R_{i,j}$ adalah region lokal yang berpusat di lokasi $(i,j)$.
#
# ## 5. Dropout
#
# Dropout adalah teknik regularisasi yang mencegah overfitting dengan secara acak mematikan neuron selama training. Secara matematis, untuk setiap neuron:
#
# $$\begin{cases}
# x/p & \text{dengan probabilitas } p \\
# 0 & \text{dengan probabilitas } 1-p
# \end{cases}$$
#
# dimana $p$ adalah probabilitas mempertahankan (keep probability) dan $1-p$ adalah dropout rate.
#
# ## 6. Forward Pass dalam MLP
# Dalam MLP, forward pass untuk lapisan fully-connected didefinisikan sebagai:
#
# $$z^{[l]} = W^{[l]} \cdot a^{[l-1]} + b^{[l]}$$
# $$a^{[l]} = g(z^{[l]})$$
#
# dimana:
# - $W^{[l]}$ adalah matriks bobot untuk lapisan ke-l
# - $a^{[l-1]}$ adalah aktivasi dari lapisan sebelumnya
# - $b^{[l]}$ adalah vektor bias
# - $g$ adalah fungsi aktivasi (seperti ReLU)
# - $z^{[l]}$ adalah input terbobot
# - $a^{[l]}$ adalah output lapisan
#
# ## 7. Fungsi Loss Cross-Entropy
# Cross-entropy loss yang digunakan untuk klasifikasi multi-kelas didefinisikan sebagai:
#
# $$L = -\frac{1}{N} \sum_{i=1}^{N} \sum_{c=1}^{C} y_{i,c} \log(p_{i,c})$$
#
# dimana:
# - $N$ adalah jumlah sampel
# - $C$ adalah jumlah kelas
# - $y_{i,c}$ adalah indikator (0 atau 1) apakah kelas c adalah label yang benar untuk sampel i
# - $p_{i,c}$ adalah probabilitas yang diprediksi bahwa sampel i adalah kelas c
#
# ## 8. Optimizer Adam
# Adam (Adaptive Moment Estimation) adalah algoritma optimasi yang menggabungkan RMSprop dan momentum. Adam memperbarui bobot menggunakan rumus:
#
# $$m_t = \beta_1 \cdot m_{t-1} + (1 - \beta_1) \cdot g_t$$
# $$v_t = \beta_2 \cdot v_{t-1} + (1 - \beta_2) \cdot g_t^2$$
# $$\hat{m}_t = \frac{m_t}{1 - \beta_1^t}$$
# $$\hat{v}_t = \frac{v_t}{1 - \beta_2^t}$$
# $$\theta_t = \theta_{t-1} - \alpha \cdot \frac{\hat{m}_t}{\sqrt{\hat{v}_t} + \epsilon}$$
#
# dimana:
# - $g_t$ adalah gradien pada waktu t
# - $m_t$ dan $v_t$ adalah estimasi momen pertama dan kedua
# - $\hat{m}_t$ dan $\hat{v}_t$ adalah estimasi momen yang dikoreksi
# - $\alpha$ adalah learning rate
# - $\beta_1$ dan $\beta_2$ adalah exponential decay rates
# - $\epsilon$ adalah konstanta kecil untuk stabilitas numerik
# - $\theta_t$ adalah parameter yang diperbarui
#
# ## 9. Softmax
# Fungsi softmax digunakan pada output layer untuk mengubah logits menjadi probabilitas yang berjumlah 1:
#
# $$\text{softmax}(x)_i = \frac{e^{x_i}}{\sum_{j=1}^{k} e^{x_j}}$$
#
# dimana $x_i$ adalah nilai logit untuk kelas i dan k adalah jumlah kelas.

# %% [markdown]
# # Penjelasan Metrik Evaluasi:
# ## Akurasi
#
# $$ \text{Accuracy} = \frac{\text{True Positives} + \text{True Negatives}}{\text{Total Samples}} $$
#
# Menunjukkan seberapa sering model memprediksi dengan benar.
#
#
# ## Presisi
#
# $$ \text{Precision} = \frac{\text{True Positives}}{\text{True Negatives} + \text{False Positives}} $$
#
# Seberapa andal prediksi positif model.
#
#
# ## Recall (Sensitivity)
#
# $$ \text{Recall} = \frac{\text{True Positives}}{\text{True Positives} + \text{False Negatives}} $$
#
# Seberapa baik model menangkap kelas positif.
#
#
# ## F1-Score
#
# $$ \text{F1-Score} = 2 \times \frac{\text{Precision} \times \text{Recall}}{\text{Precision} + \text{Recall}} $$
#
# Rata-rata harmonik antara presisi dan recall.
#
#
# ## ROC (Receiver Operating Characteristic) Curve
#
# ROC Curve memplot hubungan antara True Positive Rate (TPR) dan False Positive Rate (FPR):
#
# $$ \text{True Positive Rate (TPR)} = \text{Recall} $$
#
# $$ \text{False Positive Rate (FPR)} = \frac{\text{False Positives}}{ \text{False Positives} + \text{True Negatives}} $$
#
#
# ## AUC-ROC
#
# $$ AUC = \int_{0}^{1} TPR(x) \, dx $$
#
# AUC (Area Under Curve) adalah area di bawah kurva ROC (Receiver Operating Characteristic)
